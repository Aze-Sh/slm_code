# %%
x=open(r'd://DeviceData_#001.csv').readlines()[18:]

# %%
x=[i.split(';') for i in x]

# %%
import numpy as np
x=np.array(x,dtype=int)

# %%
import matplotlib.pyplot as plt
plt.imshow(x[400:1000,1700:2300])
plt.show()

# %%
y=np.bincount(x[400:1000,1700:2300].reshape(-1))
plt.plot(np.log(1+y))
plt.show()

# %%
import matplotlib.pyplot as plt
plt.imshow(x[930:960,1740:1770])
plt.show()

# %%
y=np.bincount(x[930:960,1740:1770].reshape(-1))
plt.plot(y)
plt.show()

# %%
x[930:960,1740:1770]
# Out:
# array([[  55,   52,   61,   57,   55,   56,   84,  114,  146,  154,  171,
#          194,  230,  285,  280,  340,  300,  272,  297,  266,  208,  198,
#          197,  167,  139,  113,   76,   76,   80,   68],
#        [  52,   53,   58,   61,   63,   75,   82,  127,  155,  227,  306,
#          350,  371,  377,  399,  435,  458,  414,  384,  366,  304,  252,
#          278,  247,  182,  163,   99,   97,   94,   78],
#        [  45,   59,   62,   63,   85,   81,   97,  155,  265,  306,  356,
#          454,  504,  520,  612,  698,  689,  610,  536,  444,  475,  399,
#          365,  341,  249,  225,  126,  125,   98,   75],
#        [  48,   48,   60,   70,   98,  156,  156,  194,  338,  419,  553,
#          654,  864,  871,  878,  970, 1070, 1014,  906,  770,  715,  589,
#          529,  551,  406,  276,  220,  136,  148,  107],
#        [  50,   55,   78,   75,  149,  165,  186,  310,  384,  559,  724,
#          959,  964, 1243, 1320, 1401, 1537, 1401, 1252, 1089,  910,  776,
# ...
