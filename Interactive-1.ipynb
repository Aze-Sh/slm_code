# %% [markdown]
# Connected to py312 (Python 3.12.7)

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from scipy.special import laguerre,genlaguerre
from BlinkSLM import *
from SLMGeneration import SLM_class



pixelpitch=17
SLMResX=1024
SLMResY=1024
beamwaist=1e3
w0=beamwaist/pixelpitch

X,Y=np.meshgrid(np.linspace(1,SLMResX,SLMResX),np.linspace(1,SLMResY,SLMResY))
X=X-SLMResX/2
Y=Y-SLMResY/2
r=np.sqrt(X**2+Y**2)
theta=np.mod(np.arctan2(Y,X),2*np.pi)

initGaussianAmp = np.sqrt(2/np.pi)/w0*np.exp(-(r**2)/w0**2)
plt.imshow(initGaussianAmp)
plt.colorbar()
plt.show()

def Phase_LG(p,l):
    return np.mod(-l*theta+np.pi*np.heaviside(-genlaguerre(p,np.abs(l))(2*r**2/w0**2),1),2*np.pi)

p=1
l=4
plt.imshow(Phase_LG(p,l))
plt.colorbar()
plt.show()

# %%
SLM_screen=np.round(Phase_LG(p,l)/(2*np.pi)*255).astype('uint8')
plt.imshow(SLM_screen)
plt.colorbar()
plt.show()

blink_slm_correction  = np.load('Blink_SLM_correction_785_convert.npy')
plt.imshow(blink_slm_correction)
plt.colorbar()
plt.show()

SLM = SLM_class()
fresnel_lens_screen, _ = SLM.fresnel_lens_phase_generate(125,1024/2,1024/2)
plt.imshow(fresnel_lens_screen)
plt.colorbar()
plt.show()

SLM_screen_corrected = np.mod(SLM_screen+blink_slm_correction,256).astype('uint8')
plt.imshow(SLM_screen_corrected)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Demeter\Desktop\slm code\Single_LG.py:7
#       4 plt.colorbar()
#       5 plt.show()
# ----> 7 blink_slm_correction  = np.load('Blink_SLM_correction_785_convert.npy')
#       8 plt.imshow(blink_slm_correction)
#       9 plt.colorbar()
#
# File c:\Users\Demeter\anaconda3\envs\py312\Lib\site-packages\numpy\lib\npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Blink_SLM_correction_785_convert.npy'

# %%
SLM_screen=np.round(Phase_LG(p,l)/(2*np.pi)*255).astype('uint8')
plt.imshow(SLM_screen)
plt.colorbar()
plt.show()

blink_slm_correction  = np.load('Blink_SLM_correction_785_convert.npy')
plt.imshow(blink_slm_correction)
plt.colorbar()
plt.show()

SLM = SLM_class()
fresnel_lens_screen, _ = SLM.fresnel_lens_phase_generate(125,1024/2,1024/2)
plt.imshow(fresnel_lens_screen)
plt.colorbar()
plt.show()

SLM_screen_corrected = np.mod(SLM_screen+blink_slm_correction,256).astype('uint8')
plt.imshow(SLM_screen_corrected)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Demeter\Desktop\slm code\Single_LG.py:7
#       4 plt.colorbar()
#       5 plt.show()
# ----> 7 blink_slm_correction  = np.load('Blink_SLM_correction_785_convert.npy')
#       8 plt.imshow(blink_slm_correction)
#       9 plt.colorbar()
#
# File c:\Users\Demeter\anaconda3\envs\py312\Lib\site-packages\numpy\lib\npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Blink_SLM_correction_785_convert.npy'

# %%
SLM_screen=np.round(Phase_LG(p,l)/(2*np.pi)*255).astype('uint8')
plt.imshow(SLM_screen)
plt.colorbar()
plt.show()

# blink_slm_correction  = np.load('Blink_SLM_correction_785_convert.npy')
# plt.imshow(blink_slm_correction)
# plt.colorbar()
# plt.show()

SLM = SLM_class()
fresnel_lens_screen, _ = SLM.fresnel_lens_phase_generate(125,1024/2,1024/2)
plt.imshow(fresnel_lens_screen)
plt.colorbar()
plt.show()

SLM_screen_corrected = np.mod(SLM_screen).astype('uint8')
plt.imshow(SLM_screen_corrected)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Demeter\Desktop\slm code\Single_LG.py:18
#      15 plt.colorbar()
#      16 plt.show()
# ---> 18 SLM_screen_corrected = np.mod(SLM_screen).astype('uint8')
#      19 plt.imshow(SLM_screen_corrected)
#      20 plt.colorbar()
#
# TypeError: remainder() takes from 2 to 3 positional arguments but 1 were given

# %%
SLM_screen=np.round(Phase_LG(p,l)/(2*np.pi)*255).astype('uint8')
plt.imshow(SLM_screen)
plt.colorbar()
plt.show()

# blink_slm_correction  = np.load('Blink_SLM_correction_785_convert.npy')
# plt.imshow(blink_slm_correction)
# plt.colorbar()
# plt.show()

SLM = SLM_class()
fresnel_lens_screen, _ = SLM.fresnel_lens_phase_generate(125,1024/2,1024/2)
plt.imshow(fresnel_lens_screen)
plt.colorbar()
plt.show()

SLM_screen_corrected = np.mod(SLM_screen).astype('uint8')
plt.imshow(SLM_screen_corrected)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Demeter\Desktop\slm code\Single_LG.py:18
#      15 plt.colorbar()
#      16 plt.show()
# ---> 18 SLM_screen_corrected = np.mod(SLM_screen).astype('uint8')
#      19 plt.imshow(SLM_screen_corrected)
#      20 plt.colorbar()
#
# TypeError: remainder() takes from 2 to 3 positional arguments but 1 were given
