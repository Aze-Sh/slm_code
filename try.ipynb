# %%
import numpy as np
import scipy as sp
from scipy import fft
import matplotlib.pyplot as plt
from PIL import Image
import os
import time

import IMGpy
import slmpy

tophatscreen=np.load('SLM_img.npy')
tophat_screen_Corrected=IMGpy.SLM_screen_Correct(tophatscreen)

slm = slmpy.SLMdisplay(monitor=1,isImageLock = True)
slm.updateArray(tophat_screen_Corrected)
# Out:
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %%
import site
print(site.getsitepackages())
# Out:
# ['c:\\Users\\Lenovo\\AppData\\Local\\Programs\\Python\\Python311', 'c:\\Users\\Lenovo\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages']
